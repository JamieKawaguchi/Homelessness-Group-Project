# %%
# Import the modules
import pandas as pd
from pathlib import Path

# %%
# Import data for homeless policy and homeless population in two csv files
policy_data_to_load = Path("2021-HNH-State-Crim-Supplement_Edited.csv")
population_data_to_load = Path("Homeless Population by State.csv")

# Read School and Student csv files and store in Pandas dataframes
homeless_laws = pd.read_csv(policy_data_to_load)
homeless_population = pd.read_csv(population_data_to_load)

# Use pd.merge method to combine the dataframe into a single set using outer join 
homeless_merged = pd.merge(homeless_laws, homeless_population, how="outer", on=["State", "State"])
homeless_merged.head()
# Out:
#         State  Sleeping in public state- wide  \
# 0     Alabama                           False
# 1      Alaska                           False
# 2     Arizona                           False
# 3    Arkansas                           False
# 4  California                           False
#
#    Sleeping in particular public places  Camping in public state- wide  \
# 0                                 False                          False
# 1                                 False                          False
# 2                                 False                          False
# 3                                 False                          False
# 4                                 False                           True
#
#    Camping in particular public places  \
# 0                                False
# 1                                 True
# 2                                 True
# 3                                False
# 4                                 True
#
#    Sitting/lying in particular public places  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                       True
#
#    Lodging, living, or sleeping in vehicles (or parking a vehicle used as a lodging / living accom- modation)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Loitering / Loafing / Vagrancy state-wide  \
# 0                                       True
# 1                                      False
# 2                                       True
# 3                                       True
# 4                                      False
#
#    Loitering / Loafing in particular public places  Standing in Roadway  ...  \
# 0                                             True                 True  ...
# 1                                            False                False  ...
# 2                                             True                 True  ...
# 3                                             True                 True  ...
# 4                                             True                 True  ...
#
#    Panhandling in particular public places  Panhandling in particular ways  \
# 0                                     True                            True
# 1                                    False                           False
# 2                                     True                            True
# 3                                     True                           False
# 4                                    False                           False
#
#    Restrictiveness Score   Total  Per10kResidents  ChronicallyHomeless  \
# 0                      6    3752              7.4                  539
# 1                      1    2320             31.7                  576
# 2                      6   13553             18.6                 2476
# 3                      5    2459              8.1                  376
# 4                      5  171521             43.7                57760
#
#    PeopleInFamilyUnits  SoloIndividuals  UnaccompaniedYouths  Veterans
# 0                 1270             2482                  169       308
# 1                  560             1760                  186       134
# 2                 2846            10707                  917       857
# 3                  328             2131                  251        92
# 4                25538           145983                 9590     10395
#
# [5 rows x 21 columns]

# %%
# Rename columns to be more intelligible to readers

homeless_merged = homeless_merged.rename(columns={'Sleeping in public state- wide':'Sleep in public statewide',
                                                'Sleeping in particular public places':'Sleep in specific public places',
                                                'Camping in public state- wide':'Camp in public statewide',
                                                 'Camping in particular public places': 'Camp in specific public places',
                                                 'Sitting/lying in particular public places':'Lying in specific public places',
                                                 'Lodging, living, or sleeping in vehicles (or parking a vehicle used as a lodging / living accom- modation)': 'Sleep/live in vehicle',
                                                 'Loitering / Loafing / Vagrancy state-wide' : 'Loitering statewide',
                                                 'Loitering / Loafing in particular public places': 'Loiter in specific public places',
                                                 'Standing in Roadway':'Standing in road',
                                                 'Panhandling in public places state- wide':'Panhandling statewide',
                                                 'Panhandling in particular public places':'Panhandling in specific public places',
                                                 'Total':'TotalPopulation'})

# Print first five rows of dataframe with renamed columns
homeless_merged.head()
# Out:
#         State  Sleep in public statewide  Sleep in specific public places  \
# 0     Alabama                      False                            False
# 1      Alaska                      False                            False
# 2     Arizona                      False                            False
# 3    Arkansas                      False                            False
# 4  California                      False                            False
#
#    Camp in public statewide  Camp in specific public places  \
# 0                     False                           False
# 1                     False                            True
# 2                     False                            True
# 3                     False                           False
# 4                      True                            True
#
#    Lying in specific public places  Sleep/live in vehicle  \
# 0                            False                  False
# 1                            False                  False
# 2                            False                  False
# 3                            False                  False
# 4                             True                  False
#
#    Loitering statewide  Loiter in specific public places  Standing in road  \
# 0                 True                              True              True
# 1                False                             False             False
# 2                 True                              True              True
# 3                 True                              True              True
# 4                False                              True              True
#
#    ...  Panhandling in specific public places  Panhandling in particular ways  \
# 0  ...                                   True                            True
# 1  ...                                  False                           False
# 2  ...                                   True                            True
# 3  ...                                   True                           False
# 4  ...                                  False                           False
#
#    Restrictiveness Score  TotalPopulation  Per10kResidents  \
# 0                      6             3752              7.4
# 1                      1             2320             31.7
# 2                      6            13553             18.6
# 3                      5             2459              8.1
# 4                      5           171521             43.7
#
#    ChronicallyHomeless  PeopleInFamilyUnits  SoloIndividuals  \
# 0                  539                 1270             2482
# 1                  576                  560             1760
# 2                 2476                 2846            10707
# 3                  376                  328             2131
# 4                57760                25538           145983
#
#    UnaccompaniedYouths  Veterans
# 0                  169       308
# 1                  186       134
# 2                  917       857
# 3                  251        92
# 4                 9590     10395
#
# [5 rows x 21 columns]

# %%
# Create ChronicPer10k column to measure chronic homeless population per 10,000 residents

homeless_merged['ChronicPer10k'] = \
    homeless_merged['Per10kResidents'] * homeless_merged['ChronicallyHomeless'] / homeless_merged['TotalPopulation']
homeless_merged.head()
# Out:
#         State  Sleep in public statewide  Sleep in specific public places  \
# 0     Alabama                      False                            False
# 1      Alaska                      False                            False
# 2     Arizona                      False                            False
# 3    Arkansas                      False                            False
# 4  California                      False                            False
#
#    Camp in public statewide  Camp in specific public places  \
# 0                     False                           False
# 1                     False                            True
# 2                     False                            True
# 3                     False                           False
# 4                      True                            True
#
#    Lying in specific public places  Sleep/live in vehicle  \
# 0                            False                  False
# 1                            False                  False
# 2                            False                  False
# 3                            False                  False
# 4                             True                  False
#
#    Loitering statewide  Loiter in specific public places  Standing in road  \
# 0                 True                              True              True
# 1                False                             False             False
# 2                 True                              True              True
# 3                 True                              True              True
# 4                False                              True              True
#
#    ...  Panhandling in particular ways  Restrictiveness Score  \
# 0  ...                            True                      6
# 1  ...                           False                      1
# 2  ...                            True                      6
# 3  ...                           False                      5
# 4  ...                           False                      5
#
#    TotalPopulation  Per10kResidents  ChronicallyHomeless  PeopleInFamilyUnits  \
# 0             3752              7.4                  539                 1270
# 1             2320             31.7                  576                  560
# 2            13553             18.6                 2476                 2846
# 3             2459              8.1                  376                  328
# 4           171521             43.7                57760                25538
#
#    SoloIndividuals  UnaccompaniedYouths  Veterans  ChronicPer10k
# 0             2482                  169       308       1.063060
# 1             1760                  186       134       7.870345
# 2            10707                  917       857       3.398037
# 3             2131                  251        92       1.238552
# 4           145983                 9590     10395      14.716052
#
# [5 rows x 22 columns]

# %%
# Use .loc method to get pertinent columns we will need to do statistical hypothesis testing on

homeless_reduced = homeless_merged.loc[:, ['State','Restrictiveness Score','TotalPopulation','Per10kResidents','ChronicallyHomeless','ChronicPer10k']]
homeless_reduced.head(10)
# Out:
#                   State  Restrictiveness Score  TotalPopulation  \
# 0               Alabama                      6             3752
# 1                Alaska                      1             2320
# 2               Arizona                      6            13553
# 3              Arkansas                      5             2459
# 4            California                      5           171521
# 5              Colorado                      2            10397
# 6           Connecticut                      3             2930
# 7              Delaware                      4             2369
# 8  District of Columbia                      2             4410
# 9               Florida                      4            25959
#
#    Per10kResidents  ChronicallyHomeless  ChronicPer10k
# 0              7.4                  539       1.063060
# 1             31.7                  576       7.870345
# 2             18.6                 2476       3.398037
# 3              8.1                  376       1.238552
# 4             43.7                57760      14.716052
# 5             17.9                 3466       5.967241
# 6              8.1                  117       0.323447
# 7             23.6                  196       1.952554
# 8             65.8                 1257      18.755238
# 9             11.9                 4233       1.940472
